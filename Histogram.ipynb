# %% [markdown]
# A manual on exploiting the Mobpro batabase, with two tasks:
# 1. Histogram of nb of commuters sent from the attracted cities (unité urbaine)
# 2. ESOPE map

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
from shapely.geometry import Point, Polygon
import shapely.geometry
import shapely.wkt
from shapely.geometry import LineString
import seaborn as sns

from matplotlib.colors import ListedColormap  
from mpl_toolkits.axes_grid1 import make_axes_locatable

#from pysal.lib import weights
import networkx as nx
#import momepy
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

import geopy.distance
from math import sin, cos, sqrt, atan2, radians
from numpy import arcsin as asin
from typing import Tuple

# %%
data = pd.read_csv("Data/nantes_2018_simplifie_VMG_V2.csv", sep=";", dtype={'DCLT': 'str', 'COMMUNE': 'str','ARM':'str','REGION':'str','REGLT':'str'} ) 

communes = pd.read_csv("Data/communes.csv", sep=";", dtype={'insee': 'str'} )

"""paris_mar_lyon = pd.read_csv('C:/Users/kangl/Desktop/données/emploi/broto/Mirabel_2011/commune_2018/paris_marseille_lyon.csv', dtype={'insee': 'str'} ) 
commune_paris = gpd.read_file('C:/Users/kangl/Desktop/données/shapefile/communes/communes-dile-de-france-au-01-janvier/communes-dile-de-france-au-01-janvier.shp')
commune_france = gpd.read_file('C:/Users/kangl/Desktop/données/shapefile/France-entier/FR-metropolitaine/commune-2022/FR-commune.shp')"""
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3369: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# "paris_mar_lyon = pd.read_csv('C:/Users/kangl/Desktop/données/emploi/broto/Mirabel_2011/commune_2018/paris_marseille_lyon.csv', dtype={'insee': 'str'} ) \ncommune_paris = gpd.read_file('C:/Users/kangl/Desktop/données/shapefile/communes/communes-dile-de-france-au-01-janvier/communes-dile-de-france-au-01-janvier.shp')\ncommune_france = gpd.read_file('C:/Users/kangl/Desktop/données/shapefile/France-entier/FR-metropolitaine/commune-2022/FR-commune.shp')"

# %%
#drop useless columns
#commune_france = commune_france.drop(columns=['reg', 'cateaav20'])
#set the type as string
#commune_paris.insee = commune_paris.insee.astype(str)
data = data[['nomcom_O','nomcom_D','flux','distance','voy*km','VP*km','TC*km','emp_O','emp_D','actifs_O','actifs_D','O_long','O_lat','D_long','D_lat']]
communes_mans = communes[['nomcom','emp','actifs','PTOT','libuu2020']]
#region of destination IDF
#data_cut_D_IDF = data_cut[(data_cut['REGLT']=='11')].reset_index(drop=True)

# %%
data.head(20)
# Out:
#                     nomcom_O                nomcom_D         flux  \
# 14044      Beaufort-en-Anjou          Baugé-en-Anjou  99,99841892
# 20465              Les Ulmes                  Saumur  99,98790665
# 14673  Brissac Loire Aubance                  Saumur  99,89038155
# 18042        Les Ponts-de-Cé               Écouflant   99,8184061
# 39197              Le Langon       Fontenay-le-Comte  99,68611854
# 20532               Varrains                Varrains  99,62549361
# 11956            Les Touches          Nort-sur-Erdre  99,60725528
# 39355                  Luçon       Fontenay-le-Comte  99,49072141
# 36557           Les Brouzils        La Roche-sur-Yon  99,45727777
# 14678  Brissac Loire Aubance     Bellevigne-en-Layon  99,44616616
# 16773        Longué-Jumelles       Beaufort-en-Anjou  99,43569072
# 12752    Vigneux-de-Bretagne                 Sautron  99,35684476
# 11366                Sautron                 Couëron  99,07803063
# ...

# %%
filtered_communes = communes_mans[communes_mans["libuu2020"].isin(['Le Mans'])]
#explication de la ligne ci-dessus : on filtre les communes de la région Le Mans

# %%
filtered_communes
# Out:
#                       nomcom          emp       actifs      PTOT libuu2020
# 626                    Aigné  276,2695734  816,5146303    1735.0   Le Mans
# 628                 Allonnes  6214,524121  3423,408058   11276.0   Le Mans
# 633                   Arnage  3472,032098  1993,017385    5626.0   Le Mans
# 679                   Changé  1831,279491  2622,018024    6749.0   Le Mans
# 685  La Chapelle-Saint-Aubin  2226,876371  916,5008764    2368.0   Le Mans
# 711                Coulaines  2234,999004  2382,525634    7895.0   Le Mans
# 757                Guécélard  327,1127313  1298,746774    3146.0   Le Mans
# 766          Laigné-en-Belin  460,5072203  1018,738202    2353.0   Le Mans
# 790                  Le Mans  82759,53893  52338,88882  146703.0   Le Mans
# 807               La Milesse  533,4524574  1162,398964    2673.0   Le Mans
# 809           Moncé-en-Belin  471,0798287  1752,656056    3765.0   Le Mans
# ...

# %%
list_communes_mans = filtered_communes['nomcom'].tolist()

# %%
list_communes_mans
#explication de la ligne ci-dessus : on crée une liste des communes de la région Le Mans
# Out:
# ['Aigné',
#  'Allonnes',
#  'Arnage',
#  'Changé',
#  'La Chapelle-Saint-Aubin',
#  'Coulaines',
#  'Guécélard',
#  'Laigné-en-Belin',
#  'Le Mans',
#  'La Milesse',
#  'Moncé-en-Belin',
#  'Mulsanne',
#  'Ruaudin',
#  'Saint-Gervais-en-Belin',
#  'Saint-Pavace',
#  'Saint-Saturnin',
#  'Sargé-lès-le-Mans',
#  "Savigné-l'Évêque",
#  'Teloché',
#  "Yvré-l'Évêque"]

# %%
#get the active population and employment in each commune
filtered_communes['actifs'] = filtered_communes['actifs'].str.replace(",", ".", regex=False)
filtered_communes['emp'] = filtered_communes['emp'].str.replace(",", ".", regex=False)

# %%
filtered_communes
# Out:
#                       nomcom          emp       actifs      PTOT libuu2020
# 626                    Aigné  276.2695734  816.5146303    1735.0   Le Mans
# 628                 Allonnes  6214.524121  3423.408058   11276.0   Le Mans
# 633                   Arnage  3472.032098  1993.017385    5626.0   Le Mans
# 679                   Changé  1831.279491  2622.018024    6749.0   Le Mans
# 685  La Chapelle-Saint-Aubin  2226.876371  916.5008764    2368.0   Le Mans
# 711                Coulaines  2234.999004  2382.525634    7895.0   Le Mans
# 757                Guécélard  327.1127313  1298.746774    3146.0   Le Mans
# 766          Laigné-en-Belin  460.5072203  1018.738202    2353.0   Le Mans
# 790                  Le Mans  82759.53893  52338.88882  146703.0   Le Mans
# 807               La Milesse  533.4524574  1162.398964    2673.0   Le Mans
# 809           Moncé-en-Belin  471.0798287  1752.656056    3765.0   Le Mans
# ...

# %%
count_actifs = filtered_communes['actifs'].astype(float).sum()
count_emp = filtered_communes['emp'].astype(float).sum()

# %%
count_actifs
# Out:
# 82002.8412105

# %%
data.shape
# Out:
# (44565, 15)

# %%
#toutes les lignes ayant pour nomcom_D le mans
data_filtered = data[data['nomcom_D'].isin(['Le Mans'])]
data_filtered.shape
# Out:
# (456, 15)

# %%
#filtered_data_D = data[data["nomcom_D"].isin(list_communes_mans)]
#filtered_data_O = data[data["nomcom_O"].isin(list_communes_mans)]
filtered_data_D = data[data["nomcom_D"] == "Le Mans"]
filtered_data_O = data[data["nomcom_O"] == "Le Mans"]

# %%
filtered_data_D.shape
# Out:
# (456, 15)

# %%
filtered_data_O['flux'] = filtered_data_O['flux'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['distance'] = filtered_data_O['distance'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['voy*km'] = filtered_data_O['voy*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['VP*km'] = filtered_data_O['VP*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['TC*km'] = filtered_data_O['TC*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['emp_O'] = filtered_data_O['emp_O'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['emp_D'] = filtered_data_O['emp_D'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['actifs_O'] = filtered_data_O['actifs_O'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['actifs_D'] = filtered_data_O['actifs_D'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['D_long'] = filtered_data_O['D_long'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['D_lat'] = filtered_data_O['D_lat'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['O_long'] = filtered_data_O['O_long'].str.replace(",", ".", regex=False).astype(float)
filtered_data_O['O_lat'] = filtered_data_O['O_lat'].str.replace(",", ".", regex=False).astype(float)

# %%
filtered_data_D['flux'] = filtered_data_D['flux'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['distance'] = filtered_data_D['distance'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['voy*km'] = filtered_data_D['voy*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['VP*km'] = filtered_data_D['VP*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['TC*km'] = filtered_data_D['TC*km'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['emp_O'] = filtered_data_D['emp_O'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['emp_D'] = filtered_data_D['emp_D'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['actifs_O'] = filtered_data_D['actifs_O'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['actifs_D'] = filtered_data_D['actifs_D'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['D_long'] = filtered_data_D['D_long'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['D_lat'] = filtered_data_D['D_lat'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['O_long'] = filtered_data_D['O_long'].str.replace(",", ".", regex=False).astype(float)
filtered_data_D['O_lat'] = filtered_data_D['O_lat'].str.replace(",", ".", regex=False).astype(float)

# %%
filtered_data_D.shape
# Out:
# (456, 15)

# %%
filtered_data_O_wo_mans=filtered_data_O[filtered_data_O["nomcom_O"] != "Le Mans"]
filtered_data_D_wo_mans=filtered_data_D[filtered_data_D["nomcom_O"] != "Le Mans"]

# %%
filtered_data_D_wo_mans.sort_values(by='distance', ascending=False).head(60)
# Out:
#                            nomcom_O nomcom_D       flux    distance  \
# 41603           Les Sables-d'Olonne  Le Mans   4.059548  220.568020
# 40300        Moutiers-les-Mauxfaits  Le Mans   4.953475  207.487737
# 3121             La Baule-Escoublac  Le Mans   0.703030  206.458768
# 7778                      Pornichet  Le Mans   1.025063  205.022908
# 10695                 Saint-Nazaire  Le Mans   3.056121  200.027812
# 7663                         Pornic  Le Mans   6.973254  194.516681
# 5423            Montoir-de-Bretagne  Le Mans   5.050161  190.698207
# 41296              La Roche-sur-Yon  Le Mans   0.985295  190.423266
# 283                 Chaumes-en-Retz  Le Mans   4.952430  184.578394
# 6857                       Paimbœuf  Le Mans   4.926442  184.294179
# 7480                    Pontchâteau  Le Mans   1.000589  182.479225
# 10877                Sainte-Pazanne  Le Mans   5.000000  181.851238
# 11006  Saint-Philbert-de-Grand-Lieu  Le Mans   5.000000  173.492049
# ...

# %%
fig, ax = plt.subplots(figsize=(25,15))

#ax.set(xticks=range(10), xlim=[0, 500])
distance = filtered_data_D_wo_mans.distance
weight = filtered_data_D_wo_mans.flux

distance_pre50 = distance[distance<50]
distance_post50 = distance[distance>=50]
weight_pre50 = weight[distance<50]
weight_post50 = weight[distance>=50]

plt.hist(distance_pre50 , color = 'gold', edgecolor = 'black',weights =weight_pre50, bins=int(915/25),align='mid')
plt.title('Distribution of distance of h2w trips to Le Mans, outsiders',fontsize=35)
plt.xlabel('distance(km)',fontsize=25)
plt.ylabel('Flow',fontsize=25)
plt.xticks(np.arange(0, 60, 10),fontsize=20)
plt.yticks(fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(25,15))
plt.hist(distance_post50 , color = 'gold', edgecolor = 'black',weights =weight_post50, bins=int(915/25),align='mid')
plt.title('Distribution of distance of h2w trips to Le Mans, outsiders',fontsize=35)
plt.xlabel('distance(km)',fontsize=25)
plt.ylabel('Flow',fontsize=25)
plt.xticks(np.arange(50, 300, 10),fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25,15))

ax.set(xticks=range(10), xlim=[0, 300])
distance = filtered_data_O.distance
weight = filtered_data_O.flux

plt.hist(distance, color = 'gold', edgecolor = 'black',weights =weight, bins=int(300/25),align='mid')
plt.title('Distribution des flux de travailleurs depuis le Mans',fontsize=35)
plt.xlabel('distance(km)',fontsize=25)
plt.ylabel('Flow',fontsize=25)
plt.xticks(np.arange(0, 300, 50),fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
filtered_data_D.sort_values(by='flux', ascending=False).head(10)
# Out:
#                 nomcom_O nomcom_D          flux   distance        voy*km  \
# 30558            Le Mans  Le Mans  37474.073030   0.011006    412.448175
# 26238           Allonnes  Le Mans   1592.841775   5.333492   8495.409375
# 27516             Changé  Le Mans   1296.767484   7.306784   9475.200210
# 28241          Coulaines  Le Mans   1195.734324   5.027633   6011.712990
# 31495           Mulsanne  Le Mans    936.586251   8.444913   7909.389696
# 26402             Arnage  Le Mans    930.893633   6.636291   6177.680589
# 31939   Parigné-l'Évêque  Le Mans    865.000000  14.271468  12344.819930
# 31266     Moncé-en-Belin  Le Mans    856.374756  10.053698   8609.732887
# 34036  Sargé-lès-le-Mans  Le Mans    830.880703   6.886627   5721.965202
# 34084   Savigné-l'Évêque  Le Mans    780.260330  12.398994   9674.442919
#
#               VP*km        TC*km         emp_O        emp_D      actifs_O  \
# 30558    226.191681    84.479968  82759.538930  82759.53893  52338.888820
# ...

# %%
# Filter the data for cities sending more than 100 persons to Le Mans
filtered_data_D_100 = filtered_data_D[filtered_data_D['flux'] > 100]

# %%
filtered_data_D_100.head(10)
# Out:
#                   nomcom_O nomcom_D         flux   distance        voy*km  \
# 13457               Angers  Le Mans   367.445913  80.228454  29479.617580
# 26168                Aigné  Le Mans   419.361999  11.237715   4712.670732
# 26238             Allonnes  Le Mans  1592.841775   5.333492   8495.409375
# 26294                 Amné  Le Mans   109.247419  19.021619   2078.062793
# 26402               Arnage  Le Mans   930.893633   6.636291   6177.680589
# 26675    Ballon-Saint Mars  Le Mans   295.000000  20.710427   6109.575837
# 26728            La Bazoge  Le Mans   767.731471  13.351919  10250.688100
# 26821              Beaufay  Le Mans   174.186587  20.096336   3500.512158
# 26884  Beaumont-sur-Sarthe  Le Mans   149.834069  27.045449   4052.329706
# 27053           Bonnétable  Le Mans   168.902800  28.756966   4857.132120
#
#               VP*km         TC*km         emp_O        emp_D      actifs_O  \
# 13457  11946.262320  16088.722680  85746.715950  82759.53893  56828.611350
# ...

# %%
# Create a GeoDataFrame for plotting
# Ensure the 'flux' column is in float format
filtered_data_D_100['flux'] = filtered_data_D_100['flux'].astype(float)

# Create a GeoDataFrame for plotting
gdf = gpd.GeoDataFrame(filtered_data_D_100, geometry=gpd.points_from_xy(filtered_data_D_100['O_long'], filtered_data_D_100['O_lat']))
# Add the names of the communes on the blue points
for x, y, label in zip(gdf.geometry.x, gdf.geometry.y, gdf['nomcom_O']):
    ax.text(x, y, label, fontsize=8, ha='right')

# Plot the ESOPE diagram
fig, ax = plt.subplots(figsize=(15, 15))
gdf.plot(ax=ax, color='blue', markersize=filtered_data_D_100['flux'] / 10, alpha=0.5,legend = filtered_data_D_100['nomcom_O'] , edgecolor='k')

# Add title and labels
plt.title('ESOPE Diagram of Cities Sending More Than 100 Persons to Le Mans', fontsize=20)
plt.xlabel('Longitude', fontsize=15)
plt.ylabel('Latitude', fontsize=15)

# Show the plot
plt.show()
# Out:
# /var/folders/vs/j78w2y_93f32p8h5wv38xrcm0000gn/T/ipykernel_5983/1635538638.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_D_100['flux'] = filtered_data_D_100['flux'].astype(float)

# %%
#Zoning system: concentric rings
#7 rings according in radius from geographic pole (Le mans) in km : 0-5, 5-10, 10-20, 20-40, 40-80, 80-160, >160
#Create a new column 'zone' in the data
filtered_data_D_100['zone'] = pd.cut(filtered_data_D_100['distance'], bins=[0, 5, 10, 20, 40, 80, 160, 300], labels=['0-5', '5-10', '10-20', '20-40', '40-80', '80-160', '>160'])
# Out:
# /var/folders/vs/j78w2y_93f32p8h5wv38xrcm0000gn/T/ipykernel_5983/1601648107.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_D_100['zone'] = pd.cut(filtered_data_D_100['distance'], bins=[0, 5, 10, 20, 40, 80, 160, 300], labels=['0-5', '5-10', '10-20', '20-40', '40-80', '80-160', '>160'])

# %%
filtered_data_D_100.sort_values(by='flux', ascending=False).head(10)
# Out:
#                 nomcom_O nomcom_D          flux   distance        voy*km  \
# 30558            Le Mans  Le Mans  37474.073030   0.011006    412.448175
# 26238           Allonnes  Le Mans   1592.841775   5.333492   8495.409375
# 27516             Changé  Le Mans   1296.767484   7.306784   9475.200210
# 28241          Coulaines  Le Mans   1195.734324   5.027633   6011.712990
# 31495           Mulsanne  Le Mans    936.586251   8.444913   7909.389696
# 26402             Arnage  Le Mans    930.893633   6.636291   6177.680589
# 31939   Parigné-l'Évêque  Le Mans    865.000000  14.271468  12344.819930
# 31266     Moncé-en-Belin  Le Mans    856.374756  10.053698   8609.732887
# 34036  Sargé-lès-le-Mans  Le Mans    830.880703   6.886627   5721.965202
# 34084   Savigné-l'Évêque  Le Mans    780.260330  12.398994   9674.442919
#
#               VP*km        TC*km         emp_O        emp_D      actifs_O  \
# 30558    226.191681    84.479968  82759.538930  82759.53893  52338.888820
# ...

# %%
# Ensure the 'flux' column is in float format
filtered_data_D_100['flux'] = filtered_data_D_100['flux'].astype(float)

#remove le mans
filtered_data_D_100 = filtered_data_D_100[filtered_data_D_100['nomcom_O'] != 'Le Mans']
# Out:
# /var/folders/vs/j78w2y_93f32p8h5wv38xrcm0000gn/T/ipykernel_5983/2693010743.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_D_100['flux'] = filtered_data_D_100['flux'].astype(float)

# %%
#Histogram with the flux in each zone
fig, ax = plt.subplots(figsize=(15, 15))
sns.histplot(filtered_data_D_100, x='zone', weights='flux', bins=7, discrete=True, color='blue', edgecolor='black')
plt.title('Histogram of resident workers in each zone', fontsize=20)
plt.xlabel('Zone', fontsize=15)
plt.ylabel('Workers', fontsize=15)
plt.show()

# %%
#Histogram with the local jobs in each zone
fig, ax = plt.subplots(figsize=(15, 15))
sns.histplot(filtered_data_D_100, x='zone', weights='emp_O', bins=7, discrete=True, color='blue', edgecolor='black')
plt.title('Histogram of jobs in each zone', fontsize=20)
plt.xlabel('Zone', fontsize=15)
plt.ylabel('Jobs', fontsize=15)
plt.show()

# %%
#graph of the ratio between the number of local jobs and the number of resident workers in each zone
filtered_data_D_100['ratio'] = filtered_data_D_100['emp_O'] / filtered_data_D_100['flux']
#plot the ratio with a line and not a histogram
fig, ax = plt.subplots(figsize=(15, 15))
sns.lineplot(data=filtered_data_D_100, x='zone', y='ratio', color='blue')
plt.title('Ratio of jobs to workers in each zone', fontsize=20)
plt.xlabel('Zone', fontsize=15)
plt.ylabel('Ratio', fontsize=15)
plt.show()

# %%
#local spatial densities: used vs. offered (from communal level)
#Create a new column 'density' in the data
filtered_data_D_100['density'] = filtered_data_D_100['emp_O'] / filtered_data_D_100['actifs_O']
#plot the density
fig, ax = plt.subplots(figsize=(15, 15))
sns.histplot(filtered_data_D_100, x='zone', weights='density', bins=7, discrete=True, color='blue', edgecolor='black')
plt.title('Histogram of the density of local jobs in Each Zone', fontsize=20)
plt.xlabel('Zone', fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.show()

# %%
#average home to work distance
#from ring as origin
#Create a new column 'distance' in the data
filtered_data_D_100['distance'] = filtered_data_D_100['distance'].astype(float)
#plot the distance
fig, ax = plt.subplots(figsize=(15, 15))
sns.histplot(filtered_data_D_100, x='zone', weights='distance', bins=7, discrete=True, color='blue', edgecolor='black')
plt.title('Histogram of the average home to work distance in each zone', fontsize=20)
plt.xlabel('Zone', fontsize=15)
plt.ylabel('Distance (km)', fontsize=15)
plt.show()

# %%
#isole les flux de nantes et angers
filtered_data_D_nantes = filtered_data_D[filtered_data_D['nomcom_O'] == 'Nantes']
filtered_data_D_angers = filtered_data_D[filtered_data_D['nomcom_O'] == 'Angers']
filtered_data_D_alencon = filtered_data_D[filtered_data_D['nomcom_O'] == 'Alençon']
filtered_data_D_la_ferte_bernard = filtered_data_D[filtered_data_D['nomcom_O'] == 'La Ferté-Bernard']

#filtered_data_D_angers
#filtered_data_D_nantes
# Out:
# Empty DataFrame
# Columns: [nomcom_O, nomcom_D, flux, distance, voy*km, VP*km, TC*km, emp_O, emp_D, actifs_O, actifs_D, O_long, O_lat, D_long, D_lat]
# Index: []

# %%
# Données du corridor
distances = [156, 155, 80, 0]  # Distance au Mans
actifs_cumules = [0,68, 435, 500]  # Gisement cumulé d’actifs

# Création du graphique
plt.figure(figsize=(6, 4))
plt.step(distances, actifs_cumules, where='post', label="Serpent de charge")

# Ajout des annotations pour les villes
villes = {155: "Nantes", 80: "Angers"}
for x, name in villes.items():
    y = actifs_cumules[distances.index(x)]
    plt.text(x, y, name, verticalalignment='bottom', horizontalalignment='right')

# Ajout des labels et titre
plt.xlabel("Distance au Mans sur le corridor")
plt.ylabel("Gisement cumulé d’actifs")
plt.title("Corridor Nantes - Angers - Le Mans")
plt.legend()

# Afficher le graphique
plt.show()
